# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.request import Request,urlopen
import cloudscraper

# %%
scraper = cloudscraper.create_scraper()

# %%
soup = BeautifulSoup(scraper.get("https://www.propertyguru.com.sg/property-guides/ultimate-list-of-bto-flat-prices-54099").text)

# %%
soup.find_all('div')
# Out:
# [<div class="header"><a class="logo" href="/" title="Home"></a></div>,
#  <div class="error txtC">
#  <div class="detailed-text-wrapper">
#  <div class="detailed-text">
#  <h1>Hi! We just want to make sure you are a human</h1>
#  <h4>Please enter the captcha below and we will get you on your way.<h4>
#  <br/><br/></h4></h4><p></p><form action="/property-guides/ultimate-list-of-bto-flat-prices-54099?__cf_chl_f_tk=s6BIOq27hneMsyqwo3osBUTVv7gNYQR1hdLqgvYvvQA-1666260301-0-gaNycGzNCL0" class="challenge-form interactive-form" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#  <div id="cf-please-wait">
#  <div id="spinner">
#  <div id="cf-bubbles">
#  <div class="bubbles"></div>
#  <div class="bubbles"></div>
#  <div class="bubbles"></div>
#  </div>
#  </div>
#  <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
# ...
